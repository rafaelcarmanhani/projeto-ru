# %% [markdown]
# Configurações Iniciais

# %%
#Importar bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

#Importar os dados
data = pd.read_csv('/content/dataarea2.csv', header=(0)) #arquivo gerado pelo notebook de agrupamento e limpeza

# %%
#ADICIONA COLUNAS PARA VÉSPERA E PÓS DIAS LETIVOS

#Separa os dados por dia
daily_data = data[['Ano', 'Mês', 'Dia_mês', 'dia letivo']].drop_duplicates()

#Ordena os dias
daily_data = daily_data.sort_values(by=['Ano', 'Mês', 'Dia_mês']).reset_index(drop=True)

#Aplica o deslocamento pra véspera no dataFrame diário
dia_letivo_amanha = daily_data['dia letivo'].shift(-1)
daily_data['véspera_de_dia_não_letivo'] = (dia_letivo_amanha == 0).astype(int)

#Aplica o deslocamento pra depois no dataFrame diário
dia_letivo_ontem = daily_data['dia letivo'].shift(1)
daily_data['pós_dia_não_letivo'] = (dia_letivo_ontem == 0).astype(int)

#Junta as tabelas
data = pd.merge(
    data,
    daily_data[['Ano', 'Mês', 'Dia_mês',
                'véspera_de_dia_não_letivo',
                'pós_dia_não_letivo']],
    on=['Ano', 'Mês', 'Dia_mês'],
    how='left'
)

# %%
#Descartar observações com valores que aparecem menos de 5 vezes
data = data.groupby("guarnição").filter(lambda x: len(x) >=5)
data = data.groupby("prato_principal_1").filter(lambda x: len(x) >= 5)
data = data.groupby("prato_principal_2").filter(lambda x: len(x) >= 5)
data = data.groupby("sobremesa_1").filter(lambda x: len(x) >= 5)

# %%
#Aplicando One Hot Encoding nas variáveis categóricas
data = pd.get_dummies(data, columns=['Mês','Dia_semana','Dia_mês','prato_principal_1', 'prato_principal_2', 'guarnição', 'sobremesa_1'])

#Guardando os atributos
atributos = data.drop(columns=['Total']).columns

# %%
#R2 ajustado

n = len(data) #numero de observações
p = len(atributos) #numero de atributos
print(n)
print(p)

def r2_ajustado(r2, n, p):
    return 1 - (1 - r2) * (n - 1) / (n - p - 1)
# Out:
# 426
# 164

# %% [markdown]
# coeficientes de correlação

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#Pearson
#correlacoes = data.corr()['Total'].drop('Total').sort_values(ascending=False)

#Spearman
correlacoes = data.corr(method='spearman')['Total'].drop('Total').sort_values(ascending=False)
print(correlacoes)
# Out:
# dia letivo                                       0.647844
# Mês_4                                            0.242825
# Mês_5                                            0.231331
# Dia_semana_ter                                   0.230190
# Mês_3                                            0.184425
# prato_principal_1_Carne de panela                0.136881
# guarnição_Repolho                                0.136031
# Dia_semana_qua                                   0.127058
# Mês_8                                            0.118572
# prato_principal_2_PVT                            0.105460
# sobremesa_1_Gelatina                             0.102062
# prato_principal_2_Hamburguer de lentilha         0.095630
# prato_principal_1_Estrogonofe de carne           0.095229
# guarnição_Couve                                  0.084252
# prato_principal_2_Grãos gratinados               0.084011
# Dia_mês_12                                       0.078664
# sobremesa_1_Doce de leite                        0.076004
# sobremesa_1_Iogurte                              0.075396
# sobremesa_1_Sorvete                              0.070839
# sobremesa_1_Doce de banana                       0.070222
# guarnição_Macarrão                               0.069581
# guarnição_Vagem                                  0.069027
# Dia_mês_20                                       0.067763
# prato_principal_1_Carne moída                    0.066317
# Vento_velocidade_horaria (m/s)                   0.064342
# Dia_mês_9                                        0.062958
# Mês_6                                            0.062177
# Dia_semana_ter                                   0.060351
# prato_principal_2_Lasanha de queijo              0.057176
# prato_principal_1_Hamburguer                     0.055977
# prato_principal_1_Lasanha bolonhesa              0.054777
# Dia_mês_13                                       0.051857
# guarnição_Batata                                 0.050525
# Dia_semana_qui                                   0.050319
# sobremesa_1_Mousse de maracujá                   0.048298
# Vento_rajada_maxima (m/s)                        0.047244
# prato_principal_2_Estrogonofe de PVT             0.041861
# prato_principal_1_Lombo                          0.040273
# sobremesa_1_Manjar                               0.039763
# guarnição_Acelga                                 0.039675
# Dia_mês_16                                       0.039399
# prato_principal_2_Cassoulet                      0.039286
# prato_principal_2_Almôndega de feijão            0.037043
# prato_principal_2_Lasanha de PVT                 0.033971
# sobremesa_1_Bombom                               0.032874
# Temp_min_C                                       0.030124
# Temp_max_C                                       0.026469
# prato_principal_2_Ovo cozido                     0.025011
# guarnição_Couve-flor                             0.024018
# sobremesa_1_Arroz doce                           0.023644
# Mês_10                                           0.022878
# guarnição_Creme de milho                         0.018873
# prato_principal_1_Frango empanado                0.016333
# prato_principal_1_Fricassê de frango             0.016312
# Dia_mês_8                                        0.016114
# guarnição_Purês                                  0.015462
# Dia_mês_24                                       0.015093
# prato_principal_2_Quibe de abóbora               0.014174
# guarnição_Batata palha                           0.013111
# Dia_mês_21                                       0.012998
# prato_principal_1_Cubos de pernil                0.012271
# Dia_mês_22                                       0.011847
# Dia_mês_27                                       0.010874
# Dia_mês_31                                       0.010723
# Dia_mês_15                                       0.010672
# prato_principal_1_frango assado                  0.008711
# sobremesa_1_Pudim de pão                         0.008512
# prato_principal_1_Linguiça                       0.007433
# prato_principal_2_Bife de feijão                 0.005180
# Mês_9                                            0.004722
# Dia_mês_18                                       0.003923
# prato_principal_1_Lagarto                        0.003375
# Dia_mês_4                                        0.003003
# prato_principal_2_Xadrez de grão de bico         0.002924
# prato_principal_2_Bife de grão de bico           0.001305
# prato_principal_1_Carne louca                    0.000984
# prato_principal_2_Quibe de brócolis              0.000132
# sobremesa_1_Chocolate                           -0.000548
# Dia_mês_28                                      -0.002227
# prato_principal_1_Pernil                        -0.002546
# Dia_mês_11                                      -0.003462
# Dia_mês_10                                      -0.003803
# Dia_mês_7                                       -0.005356
# Dia_mês_19                                      -0.005883
# Umid_rel_ar                                     -0.007584
# prato_principal_2_Baião de dois                 -0.007937
# guarnição_Farofa                                -0.007946
# Dia_mês_14                                      -0.008685
# prato_principal_2_Moussaka                      -0.008835
# sobremesa_1_Bananada                            -0.009172
# prato_principal_2_Almôndega de aveia            -0.009606
# prato_principal_2_Estrogonofe de grão de bico   -0.009988
# Dia_mês_26                                      -0.010099
# guarnição_Ervilha parmentier                    -0.010253
# guarnição_Cuscuz                                -0.010367
# sobremesa_1_Pé de moça                          -0.010619
# prato_principal_1_Bife                          -0.010934
# sobremesa_1_Mosaico                             -0.011032
# Dia_mês_30                                      -0.011725
# Dia_mês_23                                      -0.012153
# guarnição_Erro de leitura                       -0.012669
# Dia_mês_2                                       -0.013152
# sobremesa_1_Cocada                              -0.013210
# guarnição_Batata doce                           -0.013781
# sobremesa_1_Barra de cereais                    -0.015285
# prato_principal_2_Suflê de legumes              -0.015386
# guarnição_Cenoura                               -0.015586
# guarnição_Chuchu                                -0.015894
# prato_principal_2_Ovo frito                     -0.019771
# Dia_mês_17                                      -0.020933
# prato_principal_2_Grão de bico                  -0.022347
# prato_principal_1_Bisteca                       -0.023218
# sobremesa_1_Pudim de maria mole                 -0.023544
# Dia_mês_29                                      -0.025192
# sobremesa_1_Mousse de limão                     -0.025601
# prato_principal_2_Feijoada vegetariana          -0.026323
# prato_principal_1_Feijoada                      -0.026323
# prato_principal_2_Curry de legumes              -0.026364
# Ano                                             -0.027949
# prato_principal_2_Tomate recheado               -0.028941
# Precipitacao_mm                                 -0.029568
# prato_principal_2_Omelete                       -0.029762
# prato_principal_1_Isca de frango                -0.029887
# Dia_semana_seg                                  -0.030863
# guarnição_Legumes                               -0.031478
# Dia_mês_3                                       -0.032534
# guarnição_Nhoque                                -0.033031
# prato_principal_2_Hamburguer de PVT             -0.033609
# prato_principal_2_Lasanha de abobrinha          -0.034909
# guarnição_Polenta                               -0.035279
# sobremesa_1_Brigadeirão                         -0.037495
# sobremesa_1_Picolé                              -0.038944
# prato_principal_1_Isca de carne                 -0.039423
# guarnição_Virado                                -0.039809
# sobremesa_1_Surpresa de abacaxi                 -0.040087
# Dia_mês_5                                       -0.040205
# sobremesa_1_Flan de baunilha                    -0.040345
# guarnição_Abobrinha                             -0.048340
# Dia_mês_1                                       -0.050475
# sobremesa_1_Torrone                             -0.052340
# guarnição_Mandioca                              -0.057390
# guarnição_Repolho com cenoura                   -0.060882
# prato_principal_2_Bife de lentilha              -0.066819
# Dia_mês_25                                      -0.070527
# prato_principal_1_Filé de frango                -0.070895
# sobremesa_1_Bolinho                             -0.071831
# Mês_11                                          -0.073906
# prato_principal_1_Estrogonofe de frango         -0.080258
# Dia_mês_6                                       -0.080419
# prato_principal_2_Almôndega de ricota           -0.081723
# prato_principal_2_Batatalhoada                  -0.097038
# prato_principal_1_Peixe frito                   -0.097598
# sobremesa_1_Goiabada                            -0.104093
# prato_principal_1_Carne em cubos                -0.105803
# prato_principal_2_Grãos com queijo              -0.109256
# prato_principal_1_Filé de peixe                 -0.126046
# guarnição_Brócolis                              -0.143622
# Mês_1                                           -0.176244
# Mês_12                                          -0.211367
# Mês_2                                           -0.308252
# Mês_7                                           -0.382493
# Dia_semana_sex                                  -0.390194
# pós_dia_não_letivo                              -0.562211
# véspera_de_dia_não_letivo                       -0.626649
# Name: Total, dtype: float64

# %%
# 10 mais positivamente correlacionadas
top_10 = correlacoes.head(10)

# 10 mais negativamente correlacionadas
bottom_10 = correlacoes.tail(10)

# Gráfico 1
plt.figure()
top_10.sort_values().plot(kind='barh')
plt.title('Variáveis Mais Correlacionadas Positivamente com Total')
plt.xlabel('Correlação')
plt.show()

# Gráfico 2
plt.figure()
bottom_10.sort_values().plot(kind='barh')
plt.title('10 Variáveis Mais Correlacionadas Negativamente com Total')
plt.xlabel('Correlação')
plt.show()

# %% [markdown]
# Double machine learning

# %%
# !pip install doubleml
# Out:
# Requirement already satisfied: doubleml in /usr/local/lib/python3.12/dist-packages (0.11.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from doubleml) (1.5.3)
# Requirement already satisfied: numpy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from doubleml) (2.0.2)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from doubleml) (2.2.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from doubleml) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from doubleml) (1.6.1)
# Requirement already satisfied: statsmodels>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from doubleml) (0.14.6)
# Requirement already satisfied: optuna>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from doubleml) (4.7.0)
# Requirement already satisfied: matplotlib>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from doubleml) (3.10.0)
# Requirement already satisfied: seaborn>=0.13 in /usr/local/lib/python3.12/dist-packages (from doubleml) (0.13.2)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from doubleml) (5.24.1)
# Requirement already satisfied: mypy>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from doubleml) (1.19.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->doubleml) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->doubleml) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->doubleml) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->doubleml) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->doubleml) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->doubleml) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->doubleml) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->doubleml) (2.9.0.post0)
# Requirement already satisfied: typing_extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from mypy>=1.18.0->doubleml) (4.15.0)
# Requirement already satisfied: mypy_extensions>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from mypy>=1.18.0->doubleml) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from mypy>=1.18.0->doubleml) (1.0.4)
# Requirement already satisfied: librt>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from mypy>=1.18.0->doubleml) (0.8.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=4.6.0->doubleml) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=4.6.0->doubleml) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=4.6.0->doubleml) (2.0.46)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna>=4.6.0->doubleml) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna>=4.6.0->doubleml) (6.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->doubleml) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->doubleml) (2025.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->doubleml) (9.1.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->doubleml) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14.0->doubleml) (1.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=4.6.0->doubleml) (1.3.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9.0->doubleml) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=4.6.0->doubleml) (3.3.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna>=4.6.0->doubleml) (3.0.3)

# %%
from doubleml import DoubleMLData
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from doubleml.plm import DoubleMLPLR

#Define Y (objetivo)
y_col = 'Total'

#Define D (Variável que queremos saber o impacto)
treatment_prefixes = [
    'prato_principal_1_',
    #'prato_principal_2_',
    #'guarnição_',
    #'sobremesa_1_'
]

d_cols = [c for c in data.columns
          if any(c.startswith(p) for p in treatment_prefixes)]

#Define X (Variáveis de confusão)
x_cols = [c for c in data.columns if c not in d_cols + [y_col]]

#Criar o objeto do doubleml
dml_data = DoubleMLData(
    data,
    y_col=y_col,
    d_cols=d_cols,
    x_cols=x_cols
)

#Escolher os modelos ML
#ml_y = RandomForestRegressor(n_estimators=50, random_state=0)
ml_m = RandomForestClassifier(n_estimators=50, random_state=0) #antes aqui era classifier
ml_l = RandomForestRegressor(n_estimators=50, random_state=0)

#Rodar
dml_plr = DoubleMLPLR(
    dml_data,
    #ml_g=ml_y,    # modelo para Total ~ X
    ml_m=ml_m,    # modelo para D ~ X
    ml_l=ml_l,    # modelo para Total ~ X
    n_folds=3
)
dml_plr.fit()

#Resultados
for nome, valor in sorted(zip(d_cols, dml_plr.coef),
                          key=lambda x: x[1],
                          reverse=True):
    print(nome, "→", valor)
# Out:
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# prato_principal_1_Carne de panela → 71.62216821456465
# prato_principal_1_Cubos de pernil → 57.76929204420989
# prato_principal_1_Estrogonofe de frango → 37.254881113473814
# prato_principal_1_Filé de frango → 28.591639202081534
# prato_principal_1_Estrogonofe de carne → 26.46327459193992
# prato_principal_1_Lasanha bolonhesa → 20.938956397426733
# prato_principal_1_Hamburguer → 17.93100261820422
# prato_principal_1_frango assado → 17.434962307085026
# prato_principal_1_Bife → 16.978585652387103
# prato_principal_1_Lombo → 15.37525842319942
# prato_principal_1_Feijoada → 8.883351007423109
# prato_principal_1_Carne louca → 5.507794755316956
# prato_principal_1_Lagarto → 2.2453421011429264
# prato_principal_1_Peixe frito → 1.4381275841701102
# prato_principal_1_Fricassê de frango → -3.8087979323804113
# prato_principal_1_Linguiça → -4.593299477725098
# prato_principal_1_Carne moída → -5.537853091441359
# prato_principal_1_Frango empanado → -17.56986151103797
# prato_principal_1_Isca de carne → -19.903380332610272
# prato_principal_1_Isca de frango → -26.238117870722427
# prato_principal_1_Pernil → -29.958729068269655
# prato_principal_1_Bisteca → -48.82505116659842
# prato_principal_1_Carne em cubos → -54.2539652639114
# prato_principal_1_Filé de peixe → -106.67433081674676
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_coef = pd.DataFrame({
    "Variável": d_cols,
    "Coeficiente": dml_plr.coef
})

# remover prefixo
df_coef["Variável"] = df_coef["Variável"].str.replace("prato_principal_1_", "", regex=False)

# Ordenar do menor para o maior
df_sorted = df_coef.sort_values(by="Coeficiente")

# 10 menores (mais negativos)
bottom10 = df_sorted.head(10)

# 10 maiores (mais positivos)
top10 = df_sorted.tail(10)

# Juntar para plotar
plot_df = pd.concat([bottom10, top10])

plt.figure()
plt.barh(plot_df["Variável"], plot_df["Coeficiente"])
plt.axvline(0)  # linha no zero para referência
plt.xlabel("Coeficiente")
plt.title("Score de Preferência do prato principal 1")
plt.show()

# %%
from doubleml import DoubleMLData
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from doubleml.plm import DoubleMLPLR

#Define Y (objetivo)
y_col = 'Total'

#Define D (Variável que queremos saber o impacto)
treatment_prefixes = [
    #'prato_principal_1_',
    'prato_principal_2_',
    #'guarnição_',
    #'sobremesa_1_'
]

d_cols = [c for c in data.columns
          if any(c.startswith(p) for p in treatment_prefixes)]

#Define X (Variáveis de confusão)
x_cols = [c for c in data.columns if c not in d_cols + [y_col]]

#Criar o objeto do doubleml
dml_data = DoubleMLData(
    data,
    y_col=y_col,
    d_cols=d_cols,
    x_cols=x_cols
)

#Escolher os modelos ML
#ml_y = RandomForestRegressor(n_estimators=50, random_state=0)
ml_m = RandomForestClassifier(n_estimators=50, random_state=0) #antes aqui era classifier
ml_l = RandomForestRegressor(n_estimators=50, random_state=0)

#Rodar
dml_plr = DoubleMLPLR(
    dml_data,
    #ml_g=ml_y,    # modelo para Total ~ X
    ml_m=ml_m,    # modelo para D ~ X
    ml_l=ml_l,    # modelo para Total ~ X
    n_folds=3
)
dml_plr.fit()

#Resultados
for nome, valor in sorted(zip(d_cols, dml_plr.coef),
                          key=lambda x: x[1],
                          reverse=True):
    print(nome, "→", valor)
# Out:
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# prato_principal_2_Quibe de abóbora → 46.92696737661671
# prato_principal_2_Hamburguer de lentilha → 44.658282651273076
# prato_principal_2_Lasanha de queijo → 43.5383320867614
# prato_principal_2_Xadrez de grão de bico → 34.38923616404939
# prato_principal_2_Lasanha de PVT → 32.017487672207814
# prato_principal_2_Estrogonofe de PVT → 29.794244755981886
# prato_principal_2_Bife de grão de bico → 29.12501930104483
# prato_principal_2_PVT → 17.564599920944154
# prato_principal_2_Grãos gratinados → 16.1006585973656
# prato_principal_2_Almôndega de aveia → 15.377544411547
# prato_principal_2_Ovo cozido → 13.099097951279171
# prato_principal_2_Hamburguer de PVT → 12.894739506860402
# prato_principal_2_Moussaka → 10.238010293601604
# prato_principal_2_Tomate recheado → 10.20863252166079
# prato_principal_2_Feijoada vegetariana → 7.862352336928619
# prato_principal_2_Bife de feijão → 4.346273637374856
# prato_principal_2_Estrogonofe de grão de bico → -1.4933782955242059
# prato_principal_2_Omelete → -2.266492073380036
# prato_principal_2_Grão de bico → -4.664514343695223
# prato_principal_2_Cassoulet → -4.820221606648216
# prato_principal_2_Ovo frito → -10.014403702669266
# prato_principal_2_Almôndega de feijão → -12.755904828065288
# prato_principal_2_Curry de legumes → -15.457705410243081
# prato_principal_2_Grãos com queijo → -17.647792625169153
# prato_principal_2_Quibe de brócolis → -22.255862043499135
# prato_principal_2_Lasanha de abobrinha → -25.639503985828163
# prato_principal_2_Baião de dois → -33.49654673419719
# prato_principal_2_Batatalhoada → -44.11369602607042
# prato_principal_2_Suflê de legumes → -47.77843016682204
# prato_principal_2_Almôndega de ricota → -48.825508108490894
# prato_principal_2_Bife de lentilha → -70.56744623850554
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_coef = pd.DataFrame({
    "Variável": d_cols,
    "Coeficiente": dml_plr.coef
})

# remover prefixo
df_coef["Variável"] = df_coef["Variável"].str.replace("prato_principal_2_", "", regex=False)

# Ordenar do menor para o maior
df_sorted = df_coef.sort_values(by="Coeficiente")

# 10 menores (mais negativos)
bottom10 = df_sorted.head(10)

# 10 maiores (mais positivos)
top10 = df_sorted.tail(10)

# Juntar para plotar
plot_df = pd.concat([bottom10, top10])

plt.figure()
plt.barh(plot_df["Variável"], plot_df["Coeficiente"])
plt.axvline(0)  # linha no zero para referência
plt.xlabel("Coeficiente")
plt.title("Score de Preferência do prato principal 2")
plt.show()

# %%
from doubleml import DoubleMLData
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from doubleml.plm import DoubleMLPLR

#Define Y (objetivo)
y_col = 'Total'

#Define D (Variável que queremos saber o impacto)
treatment_prefixes = [
    #'prato_principal_1_',
    #'prato_principal_2_',
    'guarnição_',
    #'sobremesa_1_'
]

d_cols = [c for c in data.columns
          if any(c.startswith(p) for p in treatment_prefixes)]

#Define X (Variáveis de confusão)
x_cols = [c for c in data.columns if c not in d_cols + [y_col]]

#Criar o objeto do doubleml
dml_data = DoubleMLData(
    data,
    y_col=y_col,
    d_cols=d_cols,
    x_cols=x_cols
)

#Escolher os modelos ML
#ml_y = RandomForestRegressor(n_estimators=50, random_state=0)
ml_m = RandomForestClassifier(n_estimators=50, random_state=0) #antes aqui era classifier
ml_l = RandomForestRegressor(n_estimators=50, random_state=0)

#Rodar
dml_plr = DoubleMLPLR(
    dml_data,
    #ml_g=ml_y,    # modelo para Total ~ X
    ml_m=ml_m,    # modelo para D ~ X
    ml_l=ml_l,    # modelo para Total ~ X
    n_folds=3
)
dml_plr.fit()

#Resultados
for nome, valor in sorted(zip(d_cols, dml_plr.coef),
                          key=lambda x: x[1],
                          reverse=True):
    print(nome, "→", valor)
# Out:
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# guarnição_Repolho → 51.42125160875159
# guarnição_Vagem → 44.31835215540317
# guarnição_Couve → 35.59148555356688
# guarnição_Couve-flor → 28.84615089121081
# guarnição_Cuscuz → 26.30432576430294
# guarnição_Polenta → 25.74257299299203
# guarnição_Abobrinha → 24.299961332731844
# guarnição_Batata doce → 23.637758374031886
# guarnição_Macarrão → 22.08192412859381
# guarnição_Batata palha → 16.187125501621683
# guarnição_Creme de milho → 8.490400588219279
# guarnição_Erro de leitura → 5.90190203230849
# guarnição_Acelga → 4.5627069009422
# guarnição_Mandioca → 3.0013428696540587
# guarnição_Ervilha parmentier → 2.6624038057926405
# guarnição_Legumes → -3.821639980591947
# guarnição_Batata → -13.412874084856778
# guarnição_Chuchu → -14.195019531249985
# guarnição_Purês → -28.3199365814375
# guarnição_Virado → -29.286878259125544
# guarnição_Farofa → -32.26485206363055
# guarnição_Nhoque → -35.856381454524616
# guarnição_Brócolis → -37.519556289102994
# guarnição_Cenoura → -44.61859629342542
# guarnição_Repolho com cenoura → -53.70492180312787
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_coef = pd.DataFrame({
    "Variável": d_cols,
    "Coeficiente": dml_plr.coef
})

# remover prefixo
df_coef["Variável"] = df_coef["Variável"].str.replace("guarnição_", "", regex=False)

# Ordenar do menor para o maior
df_sorted = df_coef.sort_values(by="Coeficiente")

# 10 menores (mais negativos)
bottom10 = df_sorted.head(10)

# 10 maiores (mais positivos)
top10 = df_sorted.tail(10)

# Juntar para plotar
plot_df = pd.concat([bottom10, top10])

plt.figure()
plt.barh(plot_df["Variável"], plot_df["Coeficiente"])
plt.axvline(0)  # linha no zero para referência
plt.xlabel("Coeficiente")
plt.title("Score de Preferência da guarnição")
plt.show()

# %%
from doubleml import DoubleMLData
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from doubleml.plm import DoubleMLPLR

#Define Y (objetivo)
y_col = 'Total'

#Define D (Variável que queremos saber o impacto)
treatment_prefixes = [
    #'prato_principal_1_',
    #'prato_principal_2_',
    #'guarnição_',
    'sobremesa_1_'
]

d_cols = [c for c in data.columns
          if any(c.startswith(p) for p in treatment_prefixes)]

#Define X (Variáveis de confusão)
x_cols = [c for c in data.columns if c not in d_cols + [y_col]]

#Criar o objeto do doubleml
dml_data = DoubleMLData(
    data,
    y_col=y_col,
    d_cols=d_cols,
    x_cols=x_cols
)

#Escolher os modelos ML
#ml_y = RandomForestRegressor(n_estimators=50, random_state=0)
ml_m = RandomForestClassifier(n_estimators=50, random_state=0) #antes aqui era classifier
ml_l = RandomForestRegressor(n_estimators=50, random_state=0)

#Rodar
dml_plr = DoubleMLPLR(
    dml_data,
    #ml_g=ml_y,    # modelo para Total ~ X
    ml_m=ml_m,    # modelo para D ~ X
    ml_l=ml_l,    # modelo para Total ~ X
    n_folds=3
)
dml_plr.fit()

#Resultados
for nome, valor in sorted(zip(d_cols, dml_plr.coef),
                          key=lambda x: x[1],
                          reverse=True):
    print(nome, "→", valor)
# Out:
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# sobremesa_1_Bananada → 65.52544211782575
# sobremesa_1_Sorvete → 48.56836769355387
# sobremesa_1_Surpresa de abacaxi → 33.560888807774795
# sobremesa_1_Bombom → 27.16066184527723
# sobremesa_1_Arroz doce → 26.33930403219443
# sobremesa_1_Doce de banana → 24.166132780604247
# sobremesa_1_Mousse de maracujá → 23.39666954677558
# sobremesa_1_Mosaico → 19.476810697998005
# sobremesa_1_Flan de baunilha → 16.290840128958852
# sobremesa_1_Goiabada → 15.815511702615886
# sobremesa_1_Iogurte → 12.83186529888823
# sobremesa_1_Pudim de maria mole → 11.97712378787513
# sobremesa_1_Pé de moça → 10.52403218332701
# sobremesa_1_Brigadeirão → 8.110197057774231
# sobremesa_1_Doce de leite → 1.1728498802571405
# sobremesa_1_Cocada → 0.6305624957795898
# sobremesa_1_Pudim de pão → -4.5725703956844646
# sobremesa_1_Picolé → -4.998629951625456
# sobremesa_1_Chocolate → -9.325700080667737
# sobremesa_1_Mousse de limão → -16.155678287884015
# sobremesa_1_Gelatina → -18.40312444620145
# sobremesa_1_Manjar → -21.245250659630614
# sobremesa_1_Barra de cereais → -27.713653660996748
# sobremesa_1_Torrone → -29.0199316170555
# sobremesa_1_Bolinho → -49.95515934297346
# /usr/local/lib/python3.12/dist-packages/doubleml/utils/_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_coef = pd.DataFrame({
    "Variável": d_cols,
    "Coeficiente": dml_plr.coef
})

# remover prefixo
df_coef["Variável"] = df_coef["Variável"].str.replace("sobremesa_1_", "", regex=False)

# Ordenar do menor para o maior
df_sorted = df_coef.sort_values(by="Coeficiente")

# 10 menores (mais negativos)
bottom10 = df_sorted.head(10)

# 10 maiores (mais positivos)
top10 = df_sorted.tail(10)

# Juntar para plotar
plot_df = pd.concat([bottom10, top10])

plt.figure()
plt.barh(plot_df["Variável"], plot_df["Coeficiente"])
plt.axvline(0)  # linha no zero para referência
plt.xlabel("Coeficiente")
plt.title("Score de Preferência das sobremesas")
plt.show()

# %% [markdown]
# Algoritmos de Previsão

# %%
#Importar bibliotecas

from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

# %%
#----REGRESSÃO LINEAR MÚLTIPLA----


from sklearn.linear_model import LinearRegression


# valor a ser predito
ylabel = 'Total'

# separa y e X
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

# K-Fold externo
kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []
fold = 1

for train_index, test_index in kf.split(X):

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    lm = LinearRegression()
    lm.fit(X_train, y_train)

    y_pred = lm.predict(X_test)

    #Métricas
    R2 = r2_score(y_test, y_pred)
    lista_r2.append(R2)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: R² = {R2:.4f}")

    # ---- Plot ----
    plt.figure(figsize=(6,4))
    plt.scatter(y_test, y_pred, color='blue')
    plt.xlabel("Y real", fontsize=13)
    plt.ylabel("Predição", fontsize=13)
    plt.title(f"Regressão Linear - Fold {fold} (R² = {R2:.3f})")

    # linha y=x
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')

    plt.show()

    fold += 1

r2_reg_lin_mult = np.mean(lista_r2)
r2_dp_reg_lin_mult = np.std(lista_r2)
rmse_reg_lin_mult = np.mean(lista_rmse)
rmse_dp_reg_lin_mult = np.std(lista_rmse)
print("\nR² médio:", r2_reg_lin_mult)
print("Desvio padrão do R²:", r2_dp_reg_lin_mult)
# Out:
# Fold 1: R² = 0.7012
# Fold 2: R² = 0.6397
# Fold 3: R² = 0.7139
# Fold 4: R² = 0.6804
# Fold 5: R² = 0.7697
# R² médio: 0.7009733989782561
# Desvio padrão do R²: 0.04258996345681305

# %%
#---LASSO---

from sklearn.linear_model import LassoCV

# valor a ser predito
ylabel = 'Total'

# separa y e X
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

# K-Fold externo
kf = KFold(n_splits=5, shuffle=True,random_state=42)

lista_r2 = [] # para armezar o R2 de cada fold
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):

    # separa treino e teste do fold
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # LassoCV calcula o melhor alpha usando k-fold interno nos dados de treino do k-fold externo
    lasso = LassoCV(cv=5, max_iter=100000,random_state=42)
    lasso.fit(X_train, y_train)

    # previsão no teste
    y_pred = lasso.predict(X_test)

    # Métricas
    R2 = r2_score(y_test, y_pred)
    lista_r2.append(R2)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: hiperparâmetro alpha escolhido = {lasso.alpha_:.5f}, R2 = {R2:.4f}")

    # ---- Plot do fold ----
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Lasso: Fold {fold} (R² = {R2:.3f})")

    # linha y=x
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.show()

    fold += 1

# Média dos R2 ao final
r2_lasso = np.mean(lista_r2)
r2_dp_lasso = np.std(lista_r2)
rmse_lasso = np.mean(lista_rmse)
rmse_dp_lasso = np.std(lista_rmse)
print("\nR2 médio no K-Fold:", r2_lasso)
print("Desvio padrão do R2:", r2_dp_lasso)
# Out:
# Fold 1: hiperparâmetro alpha escolhido = 1.00552, R2 = 0.7913
# Fold 2: hiperparâmetro alpha escolhido = 0.71995, R2 = 0.7420
# Fold 3: hiperparâmetro alpha escolhido = 0.97421, R2 = 0.7498
# Fold 4: hiperparâmetro alpha escolhido = 0.95031, R2 = 0.8334
# Fold 5: hiperparâmetro alpha escolhido = 0.73936, R2 = 0.8081
# R2 médio no K-Fold: 0.7849250701073528
# Desvio padrão do R2: 0.03465228840875249

# %%
# --- Decision Tree Regressor ---

from sklearn.tree import DecisionTreeRegressor

ylabel = 'Total'

# separa y e X
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

# K-Fold externo
kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    #ajuste dos hiperparâmetros
    tree = DecisionTreeRegressor(
        max_depth=15,           # controla a profundidade da árvore
        min_samples_split=10,   # exige pelo menos 10 amostras para dividir um nó
        min_samples_leaf=4,     # cada folha precisa ter pelo menos 4 amostras
        random_state=42
    )
    tree.fit(X_train, y_train)

    y_pred = tree.predict(X_test)

    # métricas
    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot do fold ---
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Decision Tree: Fold {fold} (R² = {R2:.3f})")

    # linha y=x
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.grid(True)
    plt.show()

    fold += 1

r2_decision_tree = np.mean(lista_r2)
r2_dp_decision_tree = np.std(lista_r2)
rmse_decision_tree = np.mean(lista_rmse)
rmse_dp_decision_tree = np.std(lista_rmse)
print("\nR2 médio no K-Fold:", r2_decision_tree)
print("Desvio padrão do R2:", r2_dp_decision_tree)
# Out:
# Fold 1: R2 = 0.7228, RMSE = 113.589
# Fold 2: R2 = 0.8238, RMSE = 91.222
# Fold 3: R2 = 0.7175, RMSE = 121.284
# Fold 4: R2 = 0.7955, RMSE = 98.369
# Fold 5: R2 = 0.8676, RMSE = 85.482
# R2 médio no K-Fold: 0.785432493046745
# Desvio padrão do R2: 0.058050033567713606

# %%
# --- Random Forest Regressor ---

from sklearn.ensemble import RandomForestRegressor

ylabel = 'Total'

# separa y e X
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

# K-Fold externo
kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):
    # separa treino e teste do fold
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # modelo Random Forest
    rf = RandomForestRegressor(
        n_estimators=300,      # número de árvores
        max_depth=30,        # limitar a profundidade
        min_samples_split=2,
        min_samples_leaf=1,
        random_state=42,
    )

    rf.fit(X_train, y_train)

    # previsão
    y_pred = rf.predict(X_test)

    # métricas
    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot do fold ---
    plt.figure()
    plt.scatter(y_test, y_pred, alpha=0.7)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Random Forest: Fold {fold} (R² = {R2:.3f})")
    plt.grid(True)

    # linha y = x
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.tight_layout()
    plt.show()

    fold += 1

# Resultados finais

r2_random_forest = np.mean(lista_r2)
r2_dp_random_forest = np.std(lista_r2)
rmse_random_forest = np.mean(lista_rmse)
rmse_dp_random_forest = np.std(lista_rmse)
print("\nR2 médio no K-Fold:", r2_random_forest)
print("Desvio padrão do R2:", r2_dp_random_forest)
# Out:
# Fold 1: R2 = 0.7941, RMSE = 97.894
# Fold 2: R2 = 0.8388, RMSE = 87.253
# Fold 3: R2 = 0.7995, RMSE = 102.194
# Fold 4: R2 = 0.8516, RMSE = 83.810
# Fold 5: R2 = 0.9221, RMSE = 65.550
# R2 médio no K-Fold: 0.8412014585575293
# Desvio padrão do R2: 0.046091773027290214

# %%
# --- RIDGE REGRESSION ---

from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

ylabel = 'Total'

# separa y e X
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

# K-Fold externo
kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):

    # separa treino e teste
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # RidgeCV
    ridge = make_pipeline(
        StandardScaler(),
        RidgeCV(alphas=np.logspace(-4, 4, 100), cv=5)  # faz cv para escolher alpha
    )

    ridge.fit(X_train, y_train)

    # previsão
    y_pred = ridge.predict(X_test)

    # métricas
    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    # alpha escolhido
    alpha_escolhido = ridge.named_steps['ridgecv'].alpha_

    print(f"Fold {fold}: alpha = {alpha_escolhido:.5f}, R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot do fold ---
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Ridge: Fold {fold} (R² = {R2:.3f})")

    # linha y = x
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    fold += 1

# Resultados

r2_ridge = np.mean(lista_r2)
r2_dp_ridge = np.std(lista_r2)
rmse_ridge = np.mean(lista_rmse)
rmse_dp_ridge = np.std(lista_rmse)

print("\nR2 médio no K-Fold:", r2_ridge)
print("Desvio padrão do R2:", r2_dp_ridge)
# Out:
# Fold 1: alpha = 79.24829, R2 = 0.7146, RMSE = 115.244
# Fold 2: alpha = 54.62277, R2 = 0.6861, RMSE = 121.735
# Fold 3: alpha = 79.24829, R2 = 0.7355, RMSE = 117.358
# Fold 4: alpha = 79.24829, R2 = 0.7536, RMSE = 107.985
# Fold 5: alpha = 79.24829, R2 = 0.7708, RMSE = 112.447
# R2 médio no K-Fold: 0.7321458990443334
# Desvio padrão do R2: 0.029635196433438763

# %%
# --- ELASTIC NET REGRESSION ---

from sklearn.linear_model import ElasticNetCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

ylabel = 'Total'

# separa y e X
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

# K-Fold externo
kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):

    # separa treino e teste
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # modelo com pipeline (padronização + ElasticNetCV)
    elastic = make_pipeline(
        StandardScaler(),
        ElasticNetCV(
            l1_ratio=[0.2, 0.5, 0.8, 1],   # proporção entre L1 e L2
            alphas=np.logspace(-3, 2, 20), # força da regularização
            cv=5,                           # validação cruzada interna para escolher alpha e l1_ratio
            max_iter=100000,
            random_state=42
        )
    )

    elastic.fit(X_train, y_train)

    # previsão
    y_pred = elastic.predict(X_test)

    # métricas
    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    # parâmetros escolhidos
    modelo_cv = elastic.named_steps['elasticnetcv']
    print(f"Fold {fold}: alpha = {modelo_cv.alpha_:.5f}, l1_ratio = {modelo_cv.l1_ratio_:.2f}, R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot do fold ---
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Elastic Net: Fold {fold} (R² = {R2:.3f})")

    # linha y = x
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    fold += 1

# Resultados

r2_elastic_net = np.mean(lista_r2)
r2_dp_elastic_net = np.std(lista_r2)
rmse_elastic_net = np.mean(lista_rmse)
rmse_dp_elastic_net = np.std(lista_rmse)

print("\nR2 médio no K-Fold:", r2_elastic_net)
print("Desvio padrão do R2:", r2_dp_elastic_net)
# Out:
# Fold 1: alpha = 4.83293, l1_ratio = 1.00, R2 = 0.7932, RMSE = 98.110
# Fold 2: alpha = 4.83293, l1_ratio = 1.00, R2 = 0.7475, RMSE = 109.180
# Fold 3: alpha = 4.83293, l1_ratio = 1.00, R2 = 0.7538, RMSE = 113.240
# Fold 4: alpha = 4.83293, l1_ratio = 1.00, R2 = 0.8216, RMSE = 91.892
# Fold 5: alpha = 4.83293, l1_ratio = 1.00, R2 = 0.8200, RMSE = 99.648
# R2 médio no K-Fold: 0.7872152651900792
# Desvio padrão do R2: 0.03157585650028318

# %%
# --- GRADIENT BOOSTING REGRESSOR ---

from sklearn.ensemble import GradientBoostingRegressor

ylabel = 'Total'
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    gb = GradientBoostingRegressor(
        n_estimators=200,      # número de árvores
        learning_rate=0.05,    # taxa de aprendizado
        max_depth=3,           # profundidade das árvores
        subsample=0.8,         # amostragem parcial para evitar overfitting
        random_state=42
    )

    gb.fit(X_train, y_train)
    y_pred = gb.predict(X_test)

    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot ---
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Gradient Boosting: Fold {fold} (R² = {R2:.3f})")
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    fold += 1

r2_gradient_boosting = np.mean(lista_r2)
r2_dp_gradient_boosting = np.std(lista_r2)
rmse_gradient_boosting = np.mean(lista_rmse)
rmse_dp_gradient_boosting = np.std(lista_rmse)

print("\nR2 médio no K-Fold:", r2_gradient_boosting)
print("Desvio padrão do R2:", r2_dp_gradient_boosting)
# Out:
# Fold 1: R2 = 0.8135, RMSE = 93.173
# Fold 2: R2 = 0.8309, RMSE = 89.341
# Fold 3: R2 = 0.7945, RMSE = 103.449
# Fold 4: R2 = 0.8809, RMSE = 75.072
# Fold 5: R2 = 0.9006, RMSE = 74.043
# R2 médio no K-Fold: 0.8440949663228781
# Desvio padrão do R2: 0.04030064645090259

# %%
# --- XGBOOST REGRESSOR ---

from xgboost import XGBRegressor

ylabel = 'Total'
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Modelo XGBoost
    xgb = XGBRegressor(
        n_estimators=200,       # número de árvores
        learning_rate=0.05,     # taxa de aprendizado
        max_depth=3,            # profundidade máxima das árvores
        subsample=0.8,          # fração de amostras usadas em cada árvore
        colsample_bytree=0.8,   # fração de features usadas em cada árvore
        random_state=42,
        objective='reg:squarederror',  # função de perda para regressão
        n_jobs=-1               # usa todos os núcleos disponíveis
    )

    xgb.fit(X_train, y_train)
    y_pred = xgb.predict(X_test)

    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot ---
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"XGBoost: Fold {fold} (R² = {R2:.3f})")
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    fold += 1

r2_xgboost = np.mean(lista_r2)
r2_dp_xgboost = np.std(lista_r2)
rmse_xgboost = np.mean(lista_rmse)
rmse_dp_xgboost = np.std(lista_rmse)
print("\nR2 médio no K-Fold:", r2_xgboost)
print("Desvio padrão do R2:", r2_dp_xgboost)
# Out:
# Fold 1: R2 = 0.8149, RMSE = 92.817
# Fold 2: R2 = 0.8268, RMSE = 90.427
# Fold 3: R2 = 0.8042, RMSE = 100.990
# Fold 4: R2 = 0.8759, RMSE = 76.631
# Fold 5: R2 = 0.8985, RMSE = 74.848
# R2 médio no K-Fold: 0.8440481676492582
# Desvio padrão do R2: 0.0366428353711886

# %%
# --- EXTRA TREES REGRESSOR ---

from sklearn.ensemble import ExtraTreesRegressor


ylabel = 'Total'
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Modelo Extra Trees
    et = ExtraTreesRegressor(
        n_estimators=200,     # número de árvores
        max_depth=None,       # profundidade máxima
        min_samples_split=2,  # mínimo de amostras para dividir um nó
        min_samples_leaf=1,   # mínimo de amostras por folha
        max_features=None,    # número de features consideradas por split
        bootstrap=False,      # usa toda a amostra em vez de bootstrap
        random_state=42,
        n_jobs=-1             # usa todos os núcleos disponíveis
    )

    et.fit(X_train, y_train)
    y_pred = et.predict(X_test)

    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot ---
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Extra Trees: Fold {fold} (R² = {R2:.3f})")
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    fold += 1

r2_extra_trees = np.mean(lista_r2)
r2_dp_extra_trees = np.std(lista_r2)
rmse_extra_trees = np.mean(lista_rmse)
rmse_dp_extra_trees = np.std(lista_rmse)
print("\nR2 médio no K-Fold:", r2_extra_trees)
print("Desvio padrão do R2:", r2_dp_extra_trees)
# Out:
# Fold 1: R2 = 0.7137, RMSE = 115.433
# Fold 2: R2 = 0.8327, RMSE = 88.872
# Fold 3: R2 = 0.8119, RMSE = 98.965
# Fold 4: R2 = 0.8096, RMSE = 94.917
# Fold 5: R2 = 0.8799, RMSE = 81.388
# R2 médio no K-Fold: 0.8095848531737954
# Desvio padrão do R2: 0.05418925245342092

# %% [markdown]
# R2 ajustado nos modelos lineares (treinado no modelo inteiro)

# %%
from sklearn.linear_model import Lasso #anteriomente usou-se LassoCV
from sklearn.linear_model import Ridge #anteriomente usou-se RidgeCV
from sklearn.linear_model import ElasticNet #anteriomente usou-se ElasticNetCV

X = data.drop(columns=['Total'])
y = data['Total']

modelo = LinearRegression()
modelo.fit(X, y)
y_pred = modelo.predict(X)
r2_semcv_rl = r2_score(y, y_pred)
r2_adj_rl = r2_ajustado(r2_semcv_rl, n, p)

alpha_lasso = lasso.alpha_
modelo = Lasso(alpha=alpha_lasso)
modelo.fit(X, y)
y_pred = modelo.predict(X)
r2_semcv_lasso = r2_score(y, y_pred)
r2_adj_lasso = r2_ajustado(r2_semcv_lasso, n, p)

alpha_ridge = ridge.named_steps['ridgecv'].alpha_
modelo = Ridge(alpha=alpha_ridge)
modelo.fit(X, y)
y_pred = modelo.predict(X)
r2_semcv_ridge = r2_score(y, y_pred)
r2_adj_ridge = r2_ajustado(r2_semcv_ridge, n, p)

alpha_en = elastic.named_steps['elasticnetcv'].alpha_
l1_ratio_en = elastic.named_steps['elasticnetcv'].l1_ratio_
modelo = ElasticNet(alpha=alpha_en, l1_ratio=l1_ratio_en, max_iter=10000)
modelo.fit(X, y)
y_pred = modelo.predict(X)
r2_semcv_en = r2_score(y, y_pred)
r2_adj_en = r2_ajustado(r2_semcv_en, n, p)

# %% [markdown]
# O R2 com CV mede capacidade de generalização. O R2 sem CV mede qualidade de ajuste/aderência do modelo aos dados observados.

# %%
#COMPARAR ALGORITMOS

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

resultados = {
    'Modelo': [
        'Regressão Linear', 'Lasso', 'Decision Tree', 'Random Forest',
        'Ridge', 'Elastic Net', 'Gradient Boosting', 'XGBoost', 'Extra Trees'
    ],
    'R² médio (com CV)': [
        r2_reg_lin_mult, r2_lasso, r2_decision_tree, r2_random_forest,
        r2_ridge, r2_elastic_net, r2_gradient_boosting, r2_xgboost, r2_extra_trees
    ],
    'R² DP': [
        r2_dp_reg_lin_mult, r2_dp_lasso, r2_dp_decision_tree, r2_dp_random_forest,
        r2_dp_ridge, r2_dp_elastic_net, r2_dp_gradient_boosting, r2_dp_xgboost, r2_dp_extra_trees
    ],
    'RMSE médio': [
        rmse_reg_lin_mult, rmse_lasso, rmse_decision_tree, rmse_random_forest,
        rmse_ridge, rmse_elastic_net, rmse_gradient_boosting, rmse_xgboost, rmse_extra_trees
    ],
    'RMSE DP': [
        rmse_dp_reg_lin_mult, rmse_dp_lasso, rmse_dp_decision_tree, rmse_dp_random_forest,
        rmse_dp_ridge, rmse_dp_elastic_net, rmse_dp_gradient_boosting, rmse_dp_xgboost, rmse_dp_extra_trees
    ],
    'R² (sem CV)': [
        r2_semcv_rl, r2_semcv_lasso, np.nan,
        np.nan, r2_semcv_ridge, r2_semcv_en,
        np.nan, np.nan, np.nan
    ],
    'R² ajustado': [
        r2_adj_rl, r2_adj_lasso, np.nan,
        np.nan, r2_adj_ridge, r2_adj_en,
        np.nan, np.nan, np.nan
    ]
}

tabela = pd.DataFrame(resultados)
display(tabela.round(5))
# Out:
#               Modelo  R² médio (com CV)    R² DP  RMSE médio   RMSE DP  \
# 0   Regressão Linear            0.70097  0.04259   121.22594   5.85931
# 1              Lasso            0.78493  0.03465   102.95168   8.94758
# 2      Decision Tree            0.78543  0.05805   101.98914  13.47870
# 3      Random Forest            0.84120  0.04609    87.34030  12.80076
# 4              Ridge            0.73215  0.02964   114.95360   4.61953
# 5        Elastic Net            0.78722  0.03158   102.41413   7.74418
# 6  Gradient Boosting            0.84409  0.04030    87.01559  11.17426
# 7            XGBoost            0.84405  0.03664    87.14285   9.96388
# 8        Extra Trees            0.80958  0.05419    95.91503  11.41817
#
#    R² (sem CV)  R² ajustado
# 0      0.88796      0.81756
# 1      0.85263      0.76003
# 2          NaN          NaN
# 3          NaN          NaN
# 4      0.69148      0.49761
# 5      0.76653      0.61983
# 6          NaN          NaN
# 7          NaN          NaN
# 8          NaN          NaN

# %% [markdown]
# Treinar o modelo com o dataset inteiro para novas previsões

# %%
#Modelo Gradient Boosting

from sklearn.ensemble import GradientBoostingRegressor

gb = GradientBoostingRegressor(
        n_estimators=200,      # número de árvores
        learning_rate=0.05,    # taxa de aprendizado
        max_depth=3,           # profundidade das árvores
        subsample=0.8,         # amostragem parcial para evitar overfitting
        random_state=42
    )

gb.fit(X, y)
# Out:
# GradientBoostingRegressor(learning_rate=0.05, n_estimators=200, random_state=42,
#                           subsample=0.8)

# %%
#---OBSERVAÇÕES ESPECÍFICAS---

nova_obs = pd.DataFrame({
    'Precipitacao_mm':[0],
    'Temp_max_C':[25],
    'Temp_min_C':[20],
    'Umid_rel_ar':[50],
    'Vento_velocidade_horaria (m/s)': [3],
    'Vento_rajada_maxima (m/s)': [3],
    'Dia_mês': ['25'],
    'Dia_semana': ['ter'],
    'Mês': ['5'],
    'prato_principal_1':['lasanha à bolonhesa'],
    'prato_principal_2': ['curry de legumes'],
    'guarnição': ['legumes sautê'],
    'sobremesa_1': ['goiabada'],
    'dia letivo' : [1],
    'véspera_de_dia_não_letivo' : [0],
    'pós_dia_não_letivo' : [0]
})

nova_obs = pd.get_dummies(nova_obs)
# Reindexa para garantir mesmo formato do treino
nova_obs = nova_obs.reindex(columns=atributos, fill_value=0)

print("Predição gradient boosting:", gb.predict(nova_obs))
print('\n')
# Out:
# Predição gradient boosting: [587.77711544]
