# %% [markdown]
# Configurações Iniciais

# %%
#Importar bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

#Importar os dados
data = pd.read_csv('../data/dataarea2.csv', header=(0)) #arquivo gerado pelo notebook de agrupamento e limpeza

# %%
#ADICIONA COLUNAS PARA VÉSPERA E PÓS DIAS LETIVOS

#Separa os dados por dia
daily_data = data[['Ano', 'Mês', 'Dia_mês', 'dia letivo']].drop_duplicates()

#Ordena os dias
daily_data = daily_data.sort_values(by=['Ano', 'Mês', 'Dia_mês']).reset_index(drop=True)

#Aplica o deslocamento pra véspera no dataFrame diário
dia_letivo_amanha = daily_data['dia letivo'].shift(-1)
daily_data['véspera_de_dia_não_letivo'] = (dia_letivo_amanha == 0).astype(int)

#Aplica o deslocamento pra depois no dataFrame diário
dia_letivo_ontem = daily_data['dia letivo'].shift(1)
daily_data['pós_dia_não_letivo'] = (dia_letivo_ontem == 0).astype(int)

#Junta as tabelas
data = pd.merge(
    data,
    daily_data[['Ano', 'Mês', 'Dia_mês',
                'véspera_de_dia_não_letivo',
                'pós_dia_não_letivo']],
    on=['Ano', 'Mês', 'Dia_mês'],
    how='left'
)

# %%
#Descartar observações com valores que aparecem menos de 5 vezes
data = data.groupby("guarnição").filter(lambda x: len(x) >=5)
data = data.groupby("prato_principal_1").filter(lambda x: len(x) >= 5)
data = data.groupby("prato_principal_2").filter(lambda x: len(x) >= 5)
data = data.groupby("sobremesa_1").filter(lambda x: len(x) >= 5)

# %%
#Aplicando One Hot Encoding nas variáveis categóricas
data = pd.get_dummies(data, columns=['Mês','Dia_semana','Dia_mês','prato_principal_1', 'prato_principal_2', 'guarnição', 'sobremesa_1'])

#Guardando os atributos
atributos = data.drop(columns=['Total']).columns

# %%
#R2 ajustado

n = len(data) #numero de observações
p = len(atributos) #numero de atributos
print(n)
print(p)

def r2_ajustado(r2, n, p):
    return 1 - (1 - r2) * (n - 1) / (n - p - 1)
# Out:
# 426
# 164

# %% [markdown]
# coeficientes de correlação

# %%
#Pearson

correlacoes = data.corr()['Total'].drop('Total').sort_values(ascending=False)

# 10 mais positivamente correlacionadas
top_10 = correlacoes.head(10)

# 10 mais negativamente correlacionadas
bottom_10 = correlacoes.tail(10)

# Gráfico 1
plt.figure()
top_10.sort_values().plot(kind='barh')
plt.title('Variáveis Mais Correlacionadas Positivamente com Total')
plt.xlabel('Correlação')
plt.savefig('../images/area2/corrpos_pearson2.png', bbox_inches='tight')
plt.show()

# Gráfico 2
plt.figure()
bottom_10.sort_values().plot(kind='barh')
plt.title('10 Variáveis Mais Correlacionadas Negativamente com Total')
plt.xlabel('Correlação')
plt.savefig('../images/area2/corrneg_pearson2.png', bbox_inches='tight')
plt.show()

# %%
#Spearman
correlacoes = data.corr(method='spearman')['Total'].drop('Total').sort_values(ascending=False)

# Gráfico 1
plt.figure()
top_10.sort_values().plot(kind='barh')
plt.title('Variáveis Mais Correlacionadas Positivamente com Total')
plt.xlabel('Correlação')
plt.savefig('../images/area2/corrpos_spearman2.png', bbox_inches='tight')
plt.show()

# Gráfico 2
plt.figure()
bottom_10.sort_values().plot(kind='barh')
plt.title('10 Variáveis Mais Correlacionadas Negativamente com Total')
plt.xlabel('Correlação')
plt.savefig('../images/area2/corrneg_spearman2.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Double machine learning

# %%
# !pip install doubleml
# Out:
# Requirement already satisfied: doubleml in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.11.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from doubleml) (1.4.2)
# Requirement already satisfied: numpy>=2.0.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from doubleml) (2.1.3)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from doubleml) (2.2.3)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from doubleml) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from doubleml) (1.6.1)
# Requirement already satisfied: statsmodels>=0.14.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from doubleml) (0.14.6)
# Requirement already satisfied: optuna>=4.6.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from doubleml) (4.7.0)
# Requirement already satisfied: matplotlib>=3.9.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from doubleml) (3.10.1)
# Requirement already satisfied: seaborn>=0.13 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from doubleml) (0.13.2)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from doubleml) (6.0.0)
# Requirement already satisfied: mypy>=1.18.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from doubleml) (1.19.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.9.0->doubleml) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.9.0->doubleml) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.9.0->doubleml) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.9.0->doubleml) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.9.0->doubleml) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.9.0->doubleml) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.9.0->doubleml) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.9.0->doubleml) (2.9.0.post0)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mypy>=1.18.0->doubleml) (4.12.2)
# Requirement already satisfied: mypy_extensions>=1.0.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mypy>=1.18.0->doubleml) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mypy>=1.18.0->doubleml) (1.0.4)
# Requirement already satisfied: librt>=0.6.2 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mypy>=1.18.0->doubleml) (0.8.1)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna>=4.6.0->doubleml) (1.18.4)
# Requirement already satisfied: colorlog in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna>=4.6.0->doubleml) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna>=4.6.0->doubleml) (2.0.48)
# Requirement already satisfied: tqdm in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna>=4.6.0->doubleml) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna>=4.6.0->doubleml) (6.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=2.0.0->doubleml) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=2.0.0->doubleml) (2025.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly>=5.0.0->doubleml) (1.29.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.6.0->doubleml) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels>=0.14.0->doubleml) (1.0.2)
# Requirement already satisfied: Mako in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alembic>=1.5.0->optuna>=4.6.0->doubleml) (1.3.10)
# Requirement already satisfied: six>=1.5 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.9.0->doubleml) (1.17.0)
# Requirement already satisfied: greenlet>=1 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy>=1.4.2->optuna>=4.6.0->doubleml) (3.3.2)
# Requirement already satisfied: colorama in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from colorlog->optuna>=4.6.0->doubleml) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\sofia\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Mako->alembic>=1.5.0->optuna>=4.6.0->doubleml) (3.0.2)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\sofia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#Aplica o doubleML no prato principal 1

from doubleml import DoubleMLData
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from doubleml.plm import DoubleMLPLR

#Define Y (objetivo)
y_col = 'Total'

#Define D (Variável que queremos saber o impacto)
treatment_prefixes = [
    'prato_principal_1_',
    #'prato_principal_2_',
    #'guarnição_',
    #'sobremesa_1_'
]

d_cols = [c for c in data.columns
          if any(c.startswith(p) for p in treatment_prefixes)]

#Define X (Variáveis de confusão)
x_cols = [c for c in data.columns if c not in d_cols + [y_col]]

#Criar o objeto do doubleml
dml_data = DoubleMLData(
    data,
    y_col=y_col,
    d_cols=d_cols,
    x_cols=x_cols
)

#Escolher os modelos ML
#ml_y = RandomForestRegressor(n_estimators=50, random_state=0)
ml_m = RandomForestClassifier(n_estimators=50, random_state=0) #antes aqui era classifier
ml_l = RandomForestRegressor(n_estimators=50, random_state=0)

#Rodar
dml_plr = DoubleMLPLR(
    dml_data,
    #ml_g=ml_y,    # modelo para Total ~ X
    ml_m=ml_m,    # modelo para D ~ X
    ml_l=ml_l,    # modelo para Total ~ X
    n_folds=3
)
dml_plr.fit()

#Resultados
for nome, valor in sorted(zip(d_cols, dml_plr.coef),
                          key=lambda x: x[1],
                          reverse=True):
    print(nome, "→", valor)
# Out:
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# prato_principal_1_Cubos de pernil → 57.12678177072876
# prato_principal_1_Estrogonofe de carne → 52.99909688606314
# prato_principal_1_Carne de panela → 51.85078753351207
# prato_principal_1_Feijoada → 38.828734538534746
# prato_principal_1_Estrogonofe de frango → 36.94616639477977
# prato_principal_1_Lasanha bolonhesa → 32.39368939840359
# prato_principal_1_frango assado → 29.659696542818573
# prato_principal_1_Filé de frango → 24.094087751990514
# prato_principal_1_Hamburguer → 16.595146537241
# prato_principal_1_Carne moída → 9.553962996802182
# prato_principal_1_Lombo → 9.494559784419694
# prato_principal_1_Bife → 8.477619023577523
# prato_principal_1_Peixe frito → 3.371296947981318
# prato_principal_1_Fricassê de frango → 0.8513265038087845
# prato_principal_1_Lagarto → -1.7193736415728127
# prato_principal_1_Linguiça → -2.5886135804804313
# prato_principal_1_Pernil → -8.2913111888112
# prato_principal_1_Carne louca → -13.702741020793962
# prato_principal_1_Frango empanado → -18.316750781062247
# prato_principal_1_Isca de carne → -30.684007279506403
# prato_principal_1_Bisteca → -32.554793926247285
# prato_principal_1_Isca de frango → -41.750238322211636
# prato_principal_1_Carne em cubos → -58.94415982698409
# prato_principal_1_Filé de peixe → -94.45704103255636
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(

# %%
#Gera o gráfico do doubleML para o prato principal 1

import pandas as pd
import matplotlib.pyplot as plt

df_coef = pd.DataFrame({
    "Variável": d_cols,
    "Coeficiente": dml_plr.coef
})

# remover prefixo
df_coef["Variável"] = df_coef["Variável"].str.replace("prato_principal_1_", "", regex=False)

# Ordenar do menor para o maior
df_sorted = df_coef.sort_values(by="Coeficiente")

# 10 menores (mais negativos)
bottom10 = df_sorted.head(10)

# 10 maiores (mais positivos)
top10 = df_sorted.tail(10)

# Juntar para plotar
plot_df = pd.concat([bottom10, top10])

plt.figure()
plt.barh(plot_df["Variável"], plot_df["Coeficiente"])
plt.axvline(0)  # linha no zero para referência
plt.xlabel("Coeficiente")
plt.title("Score de Popularidade do prato principal 1")
plt.savefig('../images/area2/sppp1_2.png', bbox_inches='tight')
plt.show()

# %%
#Aplica o doubleML no prato principal 2

from doubleml import DoubleMLData
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from doubleml.plm import DoubleMLPLR

#Define Y (objetivo)
y_col = 'Total'

#Define D (Variável que queremos saber o impacto)
treatment_prefixes = [
    #'prato_principal_1_',
    'prato_principal_2_',
    #'guarnição_',
    #'sobremesa_1_'
]

d_cols = [c for c in data.columns
          if any(c.startswith(p) for p in treatment_prefixes)]

#Define X (Variáveis de confusão)
x_cols = [c for c in data.columns if c not in d_cols + [y_col]]

#Criar o objeto do doubleml
dml_data = DoubleMLData(
    data,
    y_col=y_col,
    d_cols=d_cols,
    x_cols=x_cols
)

#Escolher os modelos ML
#ml_y = RandomForestRegressor(n_estimators=50, random_state=0)
ml_m = RandomForestClassifier(n_estimators=50, random_state=0) #antes aqui era classifier
ml_l = RandomForestRegressor(n_estimators=50, random_state=0)

#Rodar
dml_plr = DoubleMLPLR(
    dml_data,
    #ml_g=ml_y,    # modelo para Total ~ X
    ml_m=ml_m,    # modelo para D ~ X
    ml_l=ml_l,    # modelo para Total ~ X
    n_folds=3
)
dml_plr.fit()

#Resultados
for nome, valor in sorted(zip(d_cols, dml_plr.coef),
                          key=lambda x: x[1],
                          reverse=True):
    print(nome, "→", valor)
# Out:
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# prato_principal_2_Estrogonofe de PVT → 44.94853963838666
# prato_principal_2_Hamburguer de lentilha → 41.531813034078034
# prato_principal_2_Tomate recheado → 39.551184195757095
# prato_principal_2_Quibe de abóbora → 38.748981469312646
# prato_principal_2_Bife de grão de bico → 38.67328717201167
# prato_principal_2_Lasanha de queijo → 32.76450914814085
# prato_principal_2_Almôndega de aveia → 17.849798363866814
# prato_principal_2_Moussaka → 17.717976740927565
# prato_principal_2_Lasanha de PVT → 15.325823601185286
# prato_principal_2_Ovo cozido → 14.157065756140558
# prato_principal_2_Feijoada vegetariana → 13.585056294779953
# prato_principal_2_Estrogonofe de grão de bico → 13.248900588417483
# prato_principal_2_Bife de feijão → 10.840404271112893
# prato_principal_2_Grãos gratinados → 8.752564628641753
# prato_principal_2_PVT → 7.935960313433673
# prato_principal_2_Cassoulet → 7.3004052684903895
# prato_principal_2_Ovo frito → 3.1820349761526203
# prato_principal_2_Grão de bico → -2.128732221908252
# prato_principal_2_Hamburguer de PVT → -8.418280871670717
# prato_principal_2_Grãos com queijo → -13.405539653140256
# prato_principal_2_Omelete → -13.711524897728873
# prato_principal_2_Quibe de brócolis → -13.911256175017632
# prato_principal_2_Baião de dois → -17.53864893336846
# prato_principal_2_Xadrez de grão de bico → -19.31166692802258
# prato_principal_2_Curry de legumes → -19.877882680699585
# prato_principal_2_Lasanha de abobrinha → -20.804855822430508
# prato_principal_2_Almôndega de ricota → -33.707738783905384
# prato_principal_2_Almôndega de feijão → -39.79126503454745
# prato_principal_2_Suflê de legumes → -40.98686068986025
# prato_principal_2_Bife de lentilha → -49.96971584274038
# prato_principal_2_Batatalhoada → -63.48045537775654
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(

# %%
#Gera o gráfico do doubleML para o prato principal 2

import pandas as pd
import matplotlib.pyplot as plt

df_coef = pd.DataFrame({
    "Variável": d_cols,
    "Coeficiente": dml_plr.coef
})

# remover prefixo
df_coef["Variável"] = df_coef["Variável"].str.replace("prato_principal_2_", "", regex=False)

# Ordenar do menor para o maior
df_sorted = df_coef.sort_values(by="Coeficiente")

# 10 menores (mais negativos)
bottom10 = df_sorted.head(10)

# 10 maiores (mais positivos)
top10 = df_sorted.tail(10)

# Juntar para plotar
plot_df = pd.concat([bottom10, top10])

plt.figure()
plt.barh(plot_df["Variável"], plot_df["Coeficiente"])
plt.axvline(0)  # linha no zero para referência
plt.xlabel("Coeficiente")
plt.title("Score de Popularidade do prato principal 2")
plt.savefig('../images/area2/sppp2_2.png', bbox_inches='tight')
plt.show()

# %%
#Aplica o doubleML a guarnição

from doubleml import DoubleMLData
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from doubleml.plm import DoubleMLPLR

#Define Y (objetivo)
y_col = 'Total'

#Define D (Variável que queremos saber o impacto)
treatment_prefixes = [
    #'prato_principal_1_',
    #'prato_principal_2_',
    'guarnição_',
    #'sobremesa_1_'
]

d_cols = [c for c in data.columns
          if any(c.startswith(p) for p in treatment_prefixes)]

#Define X (Variáveis de confusão)
x_cols = [c for c in data.columns if c not in d_cols + [y_col]]

#Criar o objeto do doubleml
dml_data = DoubleMLData(
    data,
    y_col=y_col,
    d_cols=d_cols,
    x_cols=x_cols
)

#Escolher os modelos ML
#ml_y = RandomForestRegressor(n_estimators=50, random_state=0)
ml_m = RandomForestClassifier(n_estimators=50, random_state=0) #antes aqui era classifier
ml_l = RandomForestRegressor(n_estimators=50, random_state=0)

#Rodar
dml_plr = DoubleMLPLR(
    dml_data,
    #ml_g=ml_y,    # modelo para Total ~ X
    ml_m=ml_m,    # modelo para D ~ X
    ml_l=ml_l,    # modelo para Total ~ X
    n_folds=3
)
dml_plr.fit()

#Resultados
for nome, valor in sorted(zip(d_cols, dml_plr.coef),
                          key=lambda x: x[1],
                          reverse=True):
    print(nome, "→", valor)
# Out:
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# guarnição_Macarrão → 33.174247669773635
# guarnição_Vagem → 32.64854802680564
# guarnição_Repolho → 32.38482177079339
# guarnição_Batata palha → 26.47829755320145
# guarnição_Couve → 23.847689292345773
# guarnição_Polenta → 20.526674927981716
# guarnição_Mandioca → 11.661910512266429
# guarnição_Cuscuz → 7.071031423752106
# guarnição_Creme de milho → 4.591388472543934
# guarnição_Batata → 4.168854168716423
# guarnição_Batata doce → 3.2922280313693935
# guarnição_Couve-flor → 1.297472706954353
# guarnição_Abobrinha → -0.14350581780341853
# guarnição_Ervilha parmentier → -4.302795156136737
# guarnição_Legumes → -5.934308762169678
# guarnição_Farofa → -7.021484879813902
# guarnição_Chuchu → -10.081834835848246
# guarnição_Acelga → -11.56566493514771
# guarnição_Nhoque → -12.218766550932735
# guarnição_Brócolis → -24.200229665071767
# guarnição_Purês → -25.204576865830326
# guarnição_Erro de leitura → -27.484506302521037
# guarnição_Virado → -42.689156756465216
# guarnição_Cenoura → -45.89821371947999
# guarnição_Repolho com cenoura → -47.039384615384634
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(

# %%
#Gera o gráfico do doubleML para a guarnição

import pandas as pd
import matplotlib.pyplot as plt

df_coef = pd.DataFrame({
    "Variável": d_cols,
    "Coeficiente": dml_plr.coef
})

# remover prefixo
df_coef["Variável"] = df_coef["Variável"].str.replace("guarnição_", "", regex=False)

# Ordenar do menor para o maior
df_sorted = df_coef.sort_values(by="Coeficiente")

# 10 menores (mais negativos)
bottom10 = df_sorted.head(10)

# 10 maiores (mais positivos)
top10 = df_sorted.tail(10)

# Juntar para plotar
plot_df = pd.concat([bottom10, top10])

plt.figure()
plt.barh(plot_df["Variável"], plot_df["Coeficiente"])
plt.axvline(0)  # linha no zero para referência
plt.xlabel("Coeficiente")
plt.title("Score de Popularidade da guarnição")
plt.savefig('../images/area2/spg_2.png', bbox_inches='tight')
plt.show()

# %%
#Aplica o doubleML para a sobremesa

from doubleml import DoubleMLData
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from doubleml.plm import DoubleMLPLR

#Define Y (objetivo)
y_col = 'Total'

#Define D (Variável que queremos saber o impacto)
treatment_prefixes = [
    #'prato_principal_1_',
    #'prato_principal_2_',
    #'guarnição_',
    'sobremesa_1_'
]

d_cols = [c for c in data.columns
          if any(c.startswith(p) for p in treatment_prefixes)]

#Define X (Variáveis de confusão)
x_cols = [c for c in data.columns if c not in d_cols + [y_col]]

#Criar o objeto do doubleml
dml_data = DoubleMLData(
    data,
    y_col=y_col,
    d_cols=d_cols,
    x_cols=x_cols
)

#Escolher os modelos ML
#ml_y = RandomForestRegressor(n_estimators=50, random_state=0)
ml_m = RandomForestClassifier(n_estimators=50, random_state=0) #antes aqui era classifier
ml_l = RandomForestRegressor(n_estimators=50, random_state=0)

#Rodar
dml_plr = DoubleMLPLR(
    dml_data,
    #ml_g=ml_y,    # modelo para Total ~ X
    ml_m=ml_m,    # modelo para D ~ X
    ml_l=ml_l,    # modelo para Total ~ X
    n_folds=3
)
dml_plr.fit()

#Resultados
for nome, valor in sorted(zip(d_cols, dml_plr.coef),
                          key=lambda x: x[1],
                          reverse=True):
    print(nome, "→", valor)
# Out:
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(
# sobremesa_1_Sorvete → 35.84665876297603
# sobremesa_1_Bananada → 28.12809036658142
# sobremesa_1_Iogurte → 23.474504289129516
# sobremesa_1_Mosaico → 23.35025084587564
# sobremesa_1_Pudim de maria mole → 16.657311776061775
# sobremesa_1_Goiabada → 11.935251196339127
# sobremesa_1_Brigadeirão → 10.452131220709663
# sobremesa_1_Pé de moça → 9.249517850255007
# sobremesa_1_Pudim de pão → 8.893835910039158
# sobremesa_1_Bombom → 8.308969819591969
# sobremesa_1_Arroz doce → 5.89527559055118
# sobremesa_1_Chocolate → 2.8598249949487844
# sobremesa_1_Gelatina → -1.6333464670344129
# sobremesa_1_Flan de baunilha → -1.7079496335275366
# sobremesa_1_Mousse de maracujá → -1.9996149106592875
# sobremesa_1_Cocada → -3.3950397320314925
# sobremesa_1_Doce de banana → -6.897445697178158
# sobremesa_1_Torrone → -12.714597954682173
# sobremesa_1_Manjar → -13.491043788296082
# sobremesa_1_Surpresa de abacaxi → -15.335693403983175
# sobremesa_1_Barra de cereais → -16.205500646591542
# sobremesa_1_Doce de leite → -25.334991390855173
# sobremesa_1_Mousse de limão → -30.87717317678935
# sobremesa_1_Picolé → -30.952957565366496
# sobremesa_1_Bolinho → -43.55660943514981
# C:\Users\sofia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\doubleml\utils\_checks.py:194: UserWarning: Propensity predictions from learner RandomForestClassifier(n_estimators=50, random_state=0) for ml_m are close to zero or one (eps=1e-12).
#   warnings.warn(

# %%
#Gera o gráfico do doubleML para a sobremesa

import pandas as pd
import matplotlib.pyplot as plt

df_coef = pd.DataFrame({
    "Variável": d_cols,
    "Coeficiente": dml_plr.coef
})

# remover prefixo
df_coef["Variável"] = df_coef["Variável"].str.replace("sobremesa_1_", "", regex=False)

# Ordenar do menor para o maior
df_sorted = df_coef.sort_values(by="Coeficiente")

# 10 menores (mais negativos)
bottom10 = df_sorted.head(10)

# 10 maiores (mais positivos)
top10 = df_sorted.tail(10)

# Juntar para plotar
plot_df = pd.concat([bottom10, top10])

plt.figure()
plt.barh(plot_df["Variável"], plot_df["Coeficiente"])
plt.axvline(0)  # linha no zero para referência
plt.xlabel("Coeficiente")
plt.title("Score de Popularidade das sobremesas")
plt.savefig('../images/area2/sps_2.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Algoritmos de Previsão

# %%
#Importar bibliotecas

from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

# %%
#----REGRESSÃO LINEAR MÚLTIPLA----


from sklearn.linear_model import LinearRegression


# valor a ser predito
ylabel = 'Total'

# separa y e X
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

# K-Fold externo
kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []
fold = 1

for train_index, test_index in kf.split(X):

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    lm = LinearRegression()
    lm.fit(X_train, y_train)

    y_pred = lm.predict(X_test)

    #Métricas
    R2 = r2_score(y_test, y_pred)
    lista_r2.append(R2)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: R² = {R2:.4f}")

    # ---- Plot ----
    plt.figure(figsize=(6,4))
    plt.scatter(y_test, y_pred, color='blue')
    plt.xlabel("Y real", fontsize=13)
    plt.ylabel("Predição", fontsize=13)
    plt.title(f"Regressão Linear - Fold {fold} (R² = {R2:.3f})")

    # linha y=x
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')

    plt.show()

    fold += 1

r2_reg_lin_mult = np.mean(lista_r2)
r2_dp_reg_lin_mult = np.std(lista_r2)
rmse_reg_lin_mult = np.mean(lista_rmse)
rmse_dp_reg_lin_mult = np.std(lista_rmse)
print("\nR² médio:", r2_reg_lin_mult)
print("Desvio padrão do R²:", r2_dp_reg_lin_mult)
# Out:
# Fold 1: R² = 0.7012
# Fold 2: R² = 0.6397
# Fold 3: R² = 0.7139
# Fold 4: R² = 0.6804
# Fold 5: R² = 0.7697
# R² médio: 0.7009733989782556
# Desvio padrão do R²: 0.04258996345681175

# %%
#---LASSO---

from sklearn.linear_model import LassoCV

# valor a ser predito
ylabel = 'Total'

# separa y e X
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

# K-Fold externo
kf = KFold(n_splits=5, shuffle=True,random_state=42)

lista_r2 = [] # para armezar o R2 de cada fold
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):

    # separa treino e teste do fold
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # LassoCV calcula o melhor alpha usando k-fold interno nos dados de treino do k-fold externo
    lasso = LassoCV(cv=5, max_iter=100000,random_state=42)
    lasso.fit(X_train, y_train)

    # previsão no teste
    y_pred = lasso.predict(X_test)

    # Métricas
    R2 = r2_score(y_test, y_pred)
    lista_r2.append(R2)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: hiperparâmetro alpha escolhido = {lasso.alpha_:.5f}, R2 = {R2:.4f}")

    # ---- Plot do fold ----
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Lasso: Fold {fold} (R² = {R2:.3f})")

    # linha y=x
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.show()

    fold += 1

# Média dos R2 ao final
r2_lasso = np.mean(lista_r2)
r2_dp_lasso = np.std(lista_r2)
rmse_lasso = np.mean(lista_rmse)
rmse_dp_lasso = np.std(lista_rmse)
print("\nR2 médio no K-Fold:", r2_lasso)
print("Desvio padrão do R2:", r2_dp_lasso)
# Out:
# Fold 1: hiperparâmetro alpha escolhido = 1.00552, R2 = 0.7913
# Fold 2: hiperparâmetro alpha escolhido = 0.71995, R2 = 0.7420
# Fold 3: hiperparâmetro alpha escolhido = 0.97421, R2 = 0.7498
# Fold 4: hiperparâmetro alpha escolhido = 0.95031, R2 = 0.8334
# Fold 5: hiperparâmetro alpha escolhido = 0.73936, R2 = 0.8081
# R2 médio no K-Fold: 0.7849250701073528
# Desvio padrão do R2: 0.03465228840875249

# %%
# --- Decision Tree Regressor ---

from sklearn.tree import DecisionTreeRegressor

ylabel = 'Total'

# separa y e X
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

# K-Fold externo
kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    #ajuste dos hiperparâmetros
    tree = DecisionTreeRegressor(
        max_depth=15,           # controla a profundidade da árvore
        min_samples_split=10,   # exige pelo menos 10 amostras para dividir um nó
        min_samples_leaf=4,     # cada folha precisa ter pelo menos 4 amostras
        random_state=42
    )
    tree.fit(X_train, y_train)

    y_pred = tree.predict(X_test)

    # métricas
    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot do fold ---
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Decision Tree: Fold {fold} (R² = {R2:.3f})")

    # linha y=x
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.grid(True)
    plt.show()

    fold += 1

r2_decision_tree = np.mean(lista_r2)
r2_dp_decision_tree = np.std(lista_r2)
rmse_decision_tree = np.mean(lista_rmse)
rmse_dp_decision_tree = np.std(lista_rmse)
print("\nR2 médio no K-Fold:", r2_decision_tree)
print("Desvio padrão do R2:", r2_dp_decision_tree)
# Out:
# Fold 1: R2 = 0.7228, RMSE = 113.589
# Fold 2: R2 = 0.8238, RMSE = 91.222
# Fold 3: R2 = 0.7175, RMSE = 121.284
# Fold 4: R2 = 0.7955, RMSE = 98.369
# Fold 5: R2 = 0.8676, RMSE = 85.482
# R2 médio no K-Fold: 0.785432493046745
# Desvio padrão do R2: 0.058050033567713606

# %%
# --- Random Forest Regressor ---

from sklearn.ensemble import RandomForestRegressor

ylabel = 'Total'

# separa y e X
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

# K-Fold externo
kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):
    # separa treino e teste do fold
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # modelo Random Forest
    rf = RandomForestRegressor(
        n_estimators=300,      # número de árvores
        max_depth=30,        # limitar a profundidade
        min_samples_split=2,
        min_samples_leaf=1,
        random_state=42,
    )

    rf.fit(X_train, y_train)

    # previsão
    y_pred = rf.predict(X_test)

    # métricas
    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot do fold ---
    plt.figure()
    plt.scatter(y_test, y_pred, alpha=0.7)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Random Forest: Fold {fold} (R² = {R2:.3f})")
    plt.grid(True)

    # linha y = x
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.tight_layout()
    plt.show()

    fold += 1

# Resultados finais

r2_random_forest = np.mean(lista_r2)
r2_dp_random_forest = np.std(lista_r2)
rmse_random_forest = np.mean(lista_rmse)
rmse_dp_random_forest = np.std(lista_rmse)
print("\nR2 médio no K-Fold:", r2_random_forest)
print("Desvio padrão do R2:", r2_dp_random_forest)
# Out:
# Fold 1: R2 = 0.7941, RMSE = 97.894
# Fold 2: R2 = 0.8388, RMSE = 87.253
# Fold 3: R2 = 0.7995, RMSE = 102.194
# Fold 4: R2 = 0.8516, RMSE = 83.810
# Fold 5: R2 = 0.9221, RMSE = 65.550
# R2 médio no K-Fold: 0.8412014585575293
# Desvio padrão do R2: 0.046091773027290214

# %%
# --- RIDGE REGRESSION ---

from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

ylabel = 'Total'

# separa y e X
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

# K-Fold externo
kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):

    # separa treino e teste
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # RidgeCV
    ridge = make_pipeline(
        StandardScaler(),
        RidgeCV(alphas=np.logspace(-4, 4, 100), cv=5)  # faz cv para escolher alpha
    )

    ridge.fit(X_train, y_train)

    # previsão
    y_pred = ridge.predict(X_test)

    # métricas
    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    # alpha escolhido
    alpha_escolhido = ridge.named_steps['ridgecv'].alpha_

    print(f"Fold {fold}: alpha = {alpha_escolhido:.5f}, R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot do fold ---
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Ridge: Fold {fold} (R² = {R2:.3f})")

    # linha y = x
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    fold += 1

# Resultados

r2_ridge = np.mean(lista_r2)
r2_dp_ridge = np.std(lista_r2)
rmse_ridge = np.mean(lista_rmse)
rmse_dp_ridge = np.std(lista_rmse)

print("\nR2 médio no K-Fold:", r2_ridge)
print("Desvio padrão do R2:", r2_dp_ridge)
# Out:
# Fold 1: alpha = 79.24829, R2 = 0.7146, RMSE = 115.244
# Fold 2: alpha = 54.62277, R2 = 0.6861, RMSE = 121.735
# Fold 3: alpha = 79.24829, R2 = 0.7355, RMSE = 117.358
# Fold 4: alpha = 79.24829, R2 = 0.7536, RMSE = 107.985
# Fold 5: alpha = 79.24829, R2 = 0.7708, RMSE = 112.447
# R2 médio no K-Fold: 0.732145899044333
# Desvio padrão do R2: 0.029635196433438662

# %%
# --- ELASTIC NET REGRESSION ---

from sklearn.linear_model import ElasticNetCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

ylabel = 'Total'

# separa y e X
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

# K-Fold externo
kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):

    # separa treino e teste
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # modelo com pipeline (padronização + ElasticNetCV)
    elastic = make_pipeline(
        StandardScaler(),
        ElasticNetCV(
            l1_ratio=[0.2, 0.5, 0.8, 1],   # proporção entre L1 e L2
            alphas=np.logspace(-3, 2, 20), # força da regularização
            cv=5,                           # validação cruzada interna para escolher alpha e l1_ratio
            max_iter=100000,
            random_state=42
        )
    )

    elastic.fit(X_train, y_train)

    # previsão
    y_pred = elastic.predict(X_test)

    # métricas
    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    # parâmetros escolhidos
    modelo_cv = elastic.named_steps['elasticnetcv']
    print(f"Fold {fold}: alpha = {modelo_cv.alpha_:.5f}, l1_ratio = {modelo_cv.l1_ratio_:.2f}, R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot do fold ---
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Elastic Net: Fold {fold} (R² = {R2:.3f})")

    # linha y = x
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    fold += 1

# Resultados

r2_elastic_net = np.mean(lista_r2)
r2_dp_elastic_net = np.std(lista_r2)
rmse_elastic_net = np.mean(lista_rmse)
rmse_dp_elastic_net = np.std(lista_rmse)

print("\nR2 médio no K-Fold:", r2_elastic_net)
print("Desvio padrão do R2:", r2_dp_elastic_net)
# Out:
# Fold 1: alpha = 4.83293, l1_ratio = 1.00, R2 = 0.7932, RMSE = 98.110
# Fold 2: alpha = 4.83293, l1_ratio = 1.00, R2 = 0.7475, RMSE = 109.180
# Fold 3: alpha = 4.83293, l1_ratio = 1.00, R2 = 0.7538, RMSE = 113.240
# Fold 4: alpha = 4.83293, l1_ratio = 1.00, R2 = 0.8216, RMSE = 91.892
# Fold 5: alpha = 4.83293, l1_ratio = 1.00, R2 = 0.8200, RMSE = 99.648
# R2 médio no K-Fold: 0.7872152651900792
# Desvio padrão do R2: 0.03157585650028318

# %%
# --- GRADIENT BOOSTING REGRESSOR ---

from sklearn.ensemble import GradientBoostingRegressor

ylabel = 'Total'
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    gb = GradientBoostingRegressor(
        n_estimators=200,      # número de árvores
        learning_rate=0.05,    # taxa de aprendizado
        max_depth=3,           # profundidade das árvores
        subsample=0.8,         # amostragem parcial para evitar overfitting
        random_state=42
    )

    gb.fit(X_train, y_train)
    y_pred = gb.predict(X_test)

    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot ---
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Gradient Boosting: Fold {fold} (R² = {R2:.3f})")
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    fold += 1

r2_gradient_boosting = np.mean(lista_r2)
r2_dp_gradient_boosting = np.std(lista_r2)
rmse_gradient_boosting = np.mean(lista_rmse)
rmse_dp_gradient_boosting = np.std(lista_rmse)

print("\nR2 médio no K-Fold:", r2_gradient_boosting)
print("Desvio padrão do R2:", r2_dp_gradient_boosting)
# Out:
# Fold 1: R2 = 0.8135, RMSE = 93.173
# Fold 2: R2 = 0.8309, RMSE = 89.341
# Fold 3: R2 = 0.7945, RMSE = 103.449
# Fold 4: R2 = 0.8809, RMSE = 75.072
# Fold 5: R2 = 0.9006, RMSE = 74.043
# R2 médio no K-Fold: 0.8440949663228781
# Desvio padrão do R2: 0.04030064645090259

# %%
# --- XGBOOST REGRESSOR ---

from xgboost import XGBRegressor

ylabel = 'Total'
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Modelo XGBoost
    xgb = XGBRegressor(
        n_estimators=200,       # número de árvores
        learning_rate=0.05,     # taxa de aprendizado
        max_depth=3,            # profundidade máxima das árvores
        subsample=0.8,          # fração de amostras usadas em cada árvore
        colsample_bytree=0.8,   # fração de features usadas em cada árvore
        random_state=42,
        objective='reg:squarederror',  # função de perda para regressão
        n_jobs=-1               # usa todos os núcleos disponíveis
    )

    xgb.fit(X_train, y_train)
    y_pred = xgb.predict(X_test)

    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot ---
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"XGBoost: Fold {fold} (R² = {R2:.3f})")
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    fold += 1

r2_xgboost = np.mean(lista_r2)
r2_dp_xgboost = np.std(lista_r2)
rmse_xgboost = np.mean(lista_rmse)
rmse_dp_xgboost = np.std(lista_rmse)
print("\nR2 médio no K-Fold:", r2_xgboost)
print("Desvio padrão do R2:", r2_dp_xgboost)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[56], line 3
#       1 # --- XGBOOST REGRESSOR ---
# ----> 3 from xgboost import XGBRegressor
#       5 ylabel = 'Total'
#       6 y = data[ylabel].to_numpy()
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# --- EXTRA TREES REGRESSOR ---

from sklearn.ensemble import ExtraTreesRegressor


ylabel = 'Total'
y = data[ylabel].to_numpy()
X = data.drop(columns=[ylabel]).to_numpy()

kf = KFold(n_splits=5, shuffle=True, random_state=42)

lista_r2 = []
lista_rmse = []

fold = 1
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Modelo Extra Trees
    et = ExtraTreesRegressor(
        n_estimators=200,     # número de árvores
        max_depth=None,       # profundidade máxima
        min_samples_split=2,  # mínimo de amostras para dividir um nó
        min_samples_leaf=1,   # mínimo de amostras por folha
        max_features=None,    # número de features consideradas por split
        bootstrap=False,      # usa toda a amostra em vez de bootstrap
        random_state=42,
        n_jobs=-1             # usa todos os núcleos disponíveis
    )

    et.fit(X_train, y_train)
    y_pred = et.predict(X_test)

    R2 = r2_score(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

    lista_r2.append(R2)
    lista_rmse.append(RMSE)

    print(f"Fold {fold}: R2 = {R2:.4f}, RMSE = {RMSE:.3f}")

    # --- Plot ---
    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("Y real")
    plt.ylabel("Predição")
    plt.title(f"Extra Trees: Fold {fold} (R² = {R2:.3f})")
    xl = np.linspace(min(y_test), max(y_test), 50)
    plt.plot(xl, xl, 'r--')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    fold += 1

r2_extra_trees = np.mean(lista_r2)
r2_dp_extra_trees = np.std(lista_r2)
rmse_extra_trees = np.mean(lista_rmse)
rmse_dp_extra_trees = np.std(lista_rmse)
print("\nR2 médio no K-Fold:", r2_extra_trees)
print("Desvio padrão do R2:", r2_dp_extra_trees)
# Out:
# Fold 1: R2 = 0.7137, RMSE = 115.433
# Fold 2: R2 = 0.8327, RMSE = 88.872
# Fold 3: R2 = 0.8119, RMSE = 98.965
# Fold 4: R2 = 0.8096, RMSE = 94.917
# Fold 5: R2 = 0.8799, RMSE = 81.388
# R2 médio no K-Fold: 0.8095848531737954
# Desvio padrão do R2: 0.05418925245342092

# %% [markdown]
# R2 ajustado nos modelos lineares (treinado no modelo inteiro)

# %%
from sklearn.linear_model import Lasso #anteriomente usou-se LassoCV
from sklearn.linear_model import Ridge #anteriomente usou-se RidgeCV
from sklearn.linear_model import ElasticNet #anteriomente usou-se ElasticNetCV

X = data.drop(columns=['Total'])
y = data['Total']

modelo = LinearRegression()
modelo.fit(X, y)
y_pred = modelo.predict(X)
r2_semcv_rl = r2_score(y, y_pred)
r2_adj_rl = r2_ajustado(r2_semcv_rl, n, p)

alpha_lasso = lasso.alpha_
modelo = Lasso(alpha=alpha_lasso)
modelo.fit(X, y)
y_pred = modelo.predict(X)
r2_semcv_lasso = r2_score(y, y_pred)
r2_adj_lasso = r2_ajustado(r2_semcv_lasso, n, p)

alpha_ridge = ridge.named_steps['ridgecv'].alpha_
modelo = Ridge(alpha=alpha_ridge)
modelo.fit(X, y)
y_pred = modelo.predict(X)
r2_semcv_ridge = r2_score(y, y_pred)
r2_adj_ridge = r2_ajustado(r2_semcv_ridge, n, p)

alpha_en = elastic.named_steps['elasticnetcv'].alpha_
l1_ratio_en = elastic.named_steps['elasticnetcv'].l1_ratio_
modelo = ElasticNet(alpha=alpha_en, l1_ratio=l1_ratio_en, max_iter=10000)
modelo.fit(X, y)
y_pred = modelo.predict(X)
r2_semcv_en = r2_score(y, y_pred)
r2_adj_en = r2_ajustado(r2_semcv_en, n, p)

# %% [markdown]
# O R2 com CV mede capacidade de generalização. O R2 sem CV mede qualidade de ajuste/aderência do modelo aos dados observados.

# %%
#COMPARAR ALGORITMOS

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

resultados = {
    'Modelo': [
        'Regressão Linear', 'Lasso', 'Decision Tree', 'Random Forest',
        'Ridge', 'Elastic Net', 'Gradient Boosting', 'XGBoost', 'Extra Trees'
    ],
    'R² médio (com CV)': [
        r2_reg_lin_mult, r2_lasso, r2_decision_tree, r2_random_forest,
        r2_ridge, r2_elastic_net, r2_gradient_boosting, r2_xgboost, r2_extra_trees
    ],
    'R² DP': [
        r2_dp_reg_lin_mult, r2_dp_lasso, r2_dp_decision_tree, r2_dp_random_forest,
        r2_dp_ridge, r2_dp_elastic_net, r2_dp_gradient_boosting, r2_dp_xgboost, r2_dp_extra_trees
    ],
    'RMSE médio': [
        rmse_reg_lin_mult, rmse_lasso, rmse_decision_tree, rmse_random_forest,
        rmse_ridge, rmse_elastic_net, rmse_gradient_boosting, rmse_xgboost, rmse_extra_trees
    ],
    'RMSE DP': [
        rmse_dp_reg_lin_mult, rmse_dp_lasso, rmse_dp_decision_tree, rmse_dp_random_forest,
        rmse_dp_ridge, rmse_dp_elastic_net, rmse_dp_gradient_boosting, rmse_dp_xgboost, rmse_dp_extra_trees
    ],
    'R² (sem CV)': [
        r2_semcv_rl, r2_semcv_lasso, np.nan,
        np.nan, r2_semcv_ridge, r2_semcv_en,
        np.nan, np.nan, np.nan
    ],
    'R² ajustado': [
        r2_adj_rl, r2_adj_lasso, np.nan,
        np.nan, r2_adj_ridge, r2_adj_en,
        np.nan, np.nan, np.nan
    ]
}

tabela = pd.DataFrame(resultados)
display(tabela.round(5))
# Out:
#               Modelo  R² médio (com CV)    R² DP  RMSE médio   RMSE DP  \
# 0   Regressão Linear            0.70097  0.04259   121.22594   5.85931
# 1              Lasso            0.78493  0.03465   102.95168   8.94758
# 2      Decision Tree            0.78543  0.05805   101.98914  13.47870
# 3      Random Forest            0.84120  0.04609    87.34030  12.80076
# 4              Ridge            0.73215  0.02964   114.95360   4.61953
# 5        Elastic Net            0.78722  0.03158   102.41413   7.74418
# 6  Gradient Boosting            0.84409  0.04030    87.01559  11.17426
# 7            XGBoost            0.84405  0.03664    87.14285   9.96388
# 8        Extra Trees            0.80958  0.05419    95.91503  11.41817
#
#    R² (sem CV)  R² ajustado
# 0      0.88796      0.81756
# 1      0.85263      0.76003
# 2          NaN          NaN
# 3          NaN          NaN
# 4      0.69148      0.49761
# 5      0.76653      0.61983
# 6          NaN          NaN
# 7          NaN          NaN
# 8          NaN          NaN

# %% [markdown]
# Treinar o modelo com o dataset inteiro para novas previsões

# %%
#Modelo Gradient Boosting

from sklearn.ensemble import GradientBoostingRegressor

gb = GradientBoostingRegressor(
        n_estimators=200,      # número de árvores
        learning_rate=0.05,    # taxa de aprendizado
        max_depth=3,           # profundidade das árvores
        subsample=0.8,         # amostragem parcial para evitar overfitting
        random_state=42
    )

gb.fit(X, y)
# Out:
# GradientBoostingRegressor(learning_rate=0.05, n_estimators=200, random_state=42,
#                           subsample=0.8)

# %%
#---OBSERVAÇÕES ESPECÍFICAS---

nova_obs = pd.DataFrame({
    'Precipitacao_mm':[0],
    'Temp_max_C':[25],
    'Temp_min_C':[20],
    'Umid_rel_ar':[50],
    'Vento_velocidade_horaria (m/s)': [3],
    'Vento_rajada_maxima (m/s)': [3],
    'Dia_mês': ['25'],
    'Dia_semana': ['ter'],
    'Mês': ['5'],
    'prato_principal_1':['lasanha à bolonhesa'],
    'prato_principal_2': ['curry de legumes'],
    'guarnição': ['legumes sautê'],
    'sobremesa_1': ['goiabada'],
    'dia letivo' : [1],
    'véspera_de_dia_não_letivo' : [0],
    'pós_dia_não_letivo' : [0]
})

nova_obs = pd.get_dummies(nova_obs)
# Reindexa para garantir mesmo formato do treino
nova_obs = nova_obs.reindex(columns=atributos, fill_value=0)

print("Predição gradient boosting:", gb.predict(nova_obs))
print('\n')
# Out:
# Predição gradient boosting: [587.77711544]
